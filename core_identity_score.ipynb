# %% [markdown]
# <a href="https://colab.research.google.com/github/agrigas115/core_identity_score/blob/main/core_identity_score.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Core Identity Score
#
# Predict protein fold quality from binary core/surface identity using ESM2 embeddings.
#
# Upload a PDB file and run all cells to get a predicted LDDT score.

# %%
#@title Install dependencies (takes ~1-2 min on first run)
# !pip install -q pdbfixer fair-esm torch numpy freesasa

# %%
#@title Clone repository
import os
if not os.path.exists('core_identity_score'):
    # !git clone https://github.com/agrigas115/core_identity_score
os.chdir('core_identity_score')

# %%
#@title Upload your PDB file
from google.colab import files

uploaded = files.upload()
pdb_file = list(uploaded.keys())[0]
print(f"Uploaded: {pdb_file}")

# %%
#@title Run Core Identity Score
# !python main.py "{pdb_file}"

# %%
#@title Display results
output_file = pdb_file.replace('.pdb', '_core_identity_score.txt')

with open(output_file) as f:
    print(f.read())

# %%
#@title Download results
files.download(output_file)
